# %%
# Load Dependencies
import pandas as pd
from sqlalchemy import create_engine
from secret import username, password

# %% [markdown]
# # Load Cleaned and Transformed Data

# %%
# Load Cleaned and Transformed CSV files

file = "ETL_Project/planets_exoplanets.csv"
exoplanets_df = pd.read_csv(file)
exoplanets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4886 entries, 0 to 4885
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   planet_name         4886 non-null   object
#  1   mass                1277 non-null   float64
#  2   radius              3166 non-null   float64
#  3   orbital_period_x    4051 non-null   float64
#  4   discovered_year     4296 non-null   float64
#  5   detection_type      4301 non-null   object
#  6   star_name           4251 non-null   object
#  7   star_distance       3113 non-null   float64
#  8   star_mass           3860 non-null   float64
#  9   star_radius         3707 non-null   float64
#  10  star_age            1297 non-null   float64
#  11  pl_hostname         4197 non-null   object
#  12  pl_letter           4197 non-null   object
#  13  orbital_period_y    4064 non-null   float64
#  14  eccentricity        1499 non-null   float64
#  15  planet_jup_mass     1747 non-null   float64
#  16  pl_dens             542 non-null    float64
#  17  planet_earth_mass   1747 non-null   float64
#  18  observatory_name    4197 non-null   object
#  19  telescope_name      4197 non-null   object
#  20  moons_n             4197 non-null   float64
#  21  galactic_longitude  4197 non-null   float64
#  22  galactic_latitude   4197 non-null   float64
#  23  stellar_gravity     3655 non-null   float64
# dtypes: float64(17), object(7)
# memory usage: 916.2+ KB

# %%
file = "ETL_Project/List_of_astronomical_observatories.csv"
observatories_df = pd.read_csv(file)
observatories_df
# Out:
#                                      Name Established  \
# 0    Abastumani Astrophysical Observatory        1932
# 1        Abu Reyhan-e Birooni Observatory        1976
# 2           Adirondack Public Observatory         NaN
# 3                   Adolphson Observatory        2013
# 4     Advanced Composition Explorer (ACE)        1997
# ..                                    ...         ...
# 685           York University Observatory         NaN
# 686    Yuba City Astronomical Observatory        2010
# 687       Yunnan Astronomical Observatory        1957
# 688                Zimmerwald Observatory        1956
# 689                     Zadko Observatory        2009
#
#                             Location
# 0                Abastumani, Georgia
# 1    Shiraz University, Shiraz, Iran
# 2         Tupper Lake, New York, USA
# 3            Monmouth, Illinois, USA
# 4                 Earth–Sun L1 point
# ..                               ...
# 685         Toronto, Ontario, Canada
# 686       Yuba City, California, USA
# 687           Kunming, Yunnan, China
# 688          Zimmerwald, Switzerland
# 689                Gingin, Australia
#
# [690 rows x 3 columns]

# %%
file = "ETL_Project/list_of_telescopes.csv"
telescopes_df = pd.read_csv(file)
telescopes_df
# Out:
#                                  telescope_name aperture_m aperture_in  \
# 0                     Harlan J. Smith Telescope    2.72 m      107 in)
# 1                                 UBC-Laval LMT    2.65 m      104 in)
# 2                 VLT Survey Telescope (VST)[3]    2.61 m    102.8 in)
# 3                Nordic Optical Telescope (NOT)    2.56 m      101 in)
# 4    Javalambre Survey Telescope (JAST/T250)[4]    2.55 m      100 in)
# ..                                          ...        ...         ...
# 214                       A.A. Common Reflector    0.914 m         36″
# 215                     Rosse 36-inch Telescope    0.914 m         36″
# 216                       SMARTS 0.9m Telescope    0.914 m         36″
# 217                   Spacewatch 0.9m Telescope    0.914 m         36″
# 218                              Yapp telescope    0.914 m         36″
#
#     mirror_type                           host_nationality  \
# 0        Single                                        USA
# 1        Liquid                                     Canada
# 2        Single                      Italy + ESO countries
# 3        Single  Denmark, Sweden, Iceland, Norway, Finland
# 4        Single                              International
# ..          ...                                        ...
# 214      Single                              Great Britain
# 215       Metal                              Great Britain
# 216      Single                                USA, SMARTS
# 217      Single                                        USA
# 218      Single                                       U.K.
#
#                                                   site  \
# 0                     McDonald Observatory, Texas, USA
# 1                  Vancouver, British Columbia, Canada
# 2       Paranal Observatory, Antofagasta Region, Chile
# 3                           ORM, Canary Islands, Spain
# 4                  Javalambre Observatory, Spain (Z32)
# ..                                                 ...
# 214                                      Great Britain
# 215                               Birr Castle; Ireland
# 216  Cerro Tololo Inter-American Observatory, Coqui...
# 217  Steward Observatory enclave at Kitt Peak Natio...
# 218          Royal Observatory, Greenwich+Herstmonceux
#
#                           year_built
# 0                               1969
# 1                       1992–2016[1]
# 2                               2007
# 3                               1988
# 4                                TBA
# ..                               ...
# 214                        1880–1896
# 215                             1826
# 216                             1965
# 217  Contracted 1915, Completed 1921
# 218                        1934-1990
#
# [219 rows x 7 columns]

# %% [markdown]
# ### Create database connection

# %%
connection_string = f'{username}:{password}@localhost:5432/exoplanet_db'
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['telescopes', 'observatories', 'planets']

# %% [markdown]
# ### Load DataFrames into database

# %%
observatories_df.to_sql(name='observatories', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# UndefinedColumn: column "Name" of relation "observatories" does not exist
# LINE 1: INSERT INTO observatories ("Name", "Established", "Location"...
#                                    ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-30-393b1d34f002> in <module>
# ----> 1 observatories_df.to_sql(name='observatories', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                             break
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "Name" of relation "observatories" does not exist
# LINE 1: INSERT INTO observatories ("Name", "Established", "Location"...
#                                    ^
#
# [SQL: INSERT INTO observatories ("Name", "Established", "Location") VALUES (%(Name)s, %(Established)s, %(Location)s)]
# [parameters: ({'Name': 'Abastumani Astrophysical Observatory', 'Established': '1932', 'Location': 'Abastumani, Georgia'}, {'Name': 'Abu Reyhan-e Birooni Observatory', 'Established': '1976', 'Location': 'Shiraz University,\xa0Shiraz, Iran'}, {'Name': 'Adirondack Public Observatory', 'Established': None, 'Location': 'Tupper Lake, New York, USA'}, {'Name': 'Adolphson Observatory', 'Established': '2013', 'Location': 'Monmouth, Illinois, USA'}, {'Name': 'Advanced Composition Explorer\xa0(ACE)', 'Established': '1997', 'Location': 'Earth–Sun L1 point'}, {'Name': 'Airdrie Public Observatory', 'Established': '1896', 'Location': 'Airdrie, Scotland'}, {'Name': 'Aker Observatory', 'Established': '1995', 'Location': 'Safford, Arizona, USA'}, {'Name': 'Aldershot Observatory', 'Established': '1906', 'Location': 'Aldershot,\xa0Hampshire, England'}  ... displaying 10 of 690 total bound parameter sets ...  {'Name': 'Zimmerwald Observatory', 'Established': '1956', 'Location': 'Zimmerwald, Switzerland'}, {'Name': 'Zadko Observatory', 'Established': '2009', 'Location': 'Gingin, Australia'})]
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %%
telescopes_df.to_sql(name='telescopes', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# InvalidTextRepresentation                 Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#
# InvalidTextRepresentation: invalid input syntax for type integer: "1992–2016[1]"
# LINE 1: ... 'Canada', 'Vancouver, British Columbia, Canada', '1992–2016...
#                                                              ^
#
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# <ipython-input-34-5e85c2d45606> in <module>
# ----> 1 telescopes_df.to_sql(name='telescopes', con=engine, if_exists='append', index=False)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1315         )
#    1316         table.create()
# -> 1317         table.insert(chunksize, method=method)
#    1318         if not name.isdigit() and not name.islower():
#    1319             # check for potentially case sensitivity issues (GH7815)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     667         """
#     668         data = [dict(zip(keys, row)) for row in data_iter]
# --> 669         conn.execute(self.table.insert(), data)
#     670
#     671     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1012             )
#    1013         else:
# -> 1014             return meth(self, multiparams, params)
#    1015
#    1016     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1125             )
#    1126
# -> 1127         ret = self._execute_context(
#    1128             dialect,
#    1129             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1315
#    1316         except BaseException as e:
# -> 1317             self._handle_dbapi_exception(
#    1318                 e, statement, parameters, cursor, context
#    1319             )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1509                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1510             elif should_wrap:
# -> 1511                 util.raise_(
#    1512                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1513                 )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                             break
#    1256                 if not evt_handled:
# -> 1257                     self.dialect.do_executemany(
#    1258                         cursor, statement, parameters, context
#    1259                     )
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     871     def do_executemany(self, cursor, statement, parameters, context=None):
#     872         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 873             cursor.executemany(statement, parameters)
#     874             return
#     875
#
# DataError: (psycopg2.errors.InvalidTextRepresentation) invalid input syntax for type integer: "1992–2016[1]"
# LINE 1: ... 'Canada', 'Vancouver, British Columbia, Canada', '1992–2016...
#                                                              ^
#
# [SQL: INSERT INTO telescopes (telescope_name, aperture_m, aperture_in, mirror_type, host_nationality, site, year_built) VALUES (%(telescope_name)s, %(aperture_m)s, %(aperture_in)s, %(mirror_type)s, %(host_nationality)s, %(site)s, %(year_built)s)]
# [parameters: ({'telescope_name': 'Harlan J. Smith Telescope', 'aperture_m': '2.72\xa0m ', 'aperture_in': '107\xa0in)', 'mirror_type': 'Single', 'host_nationality': 'USA', 'site': 'McDonald Observatory, Texas, USA', 'year_built': '1969'}, {'telescope_name': 'UBC-Laval LMT', 'aperture_m': '2.65\xa0m ', 'aperture_in': '104\xa0in)', 'mirror_type': 'Liquid', 'host_nationality': 'Canada', 'site': 'Vancouver, British Columbia, Canada', 'year_built': '1992–2016[1]'}, {'telescope_name': 'VLT Survey Telescope (VST)[3]', 'aperture_m': '2.61\xa0m ', 'aperture_in': '102.8\xa0in)', 'mirror_type': 'Single', 'host_nationality': 'Italy + ESO countries', 'site': 'Paranal Observatory, Antofagasta Region, Chile', 'year_built': '2007'}, {'telescope_name': 'Nordic Optical Telescope (NOT)', 'aperture_m': '2.56\xa0m ', 'aperture_in': '101\xa0in)', 'mirror_type': 'Single', 'host_nationality': 'Denmark, Sweden, Iceland, Norway, Finland', 'site': 'ORM, Canary Islands, Spain', 'year_built': '1988'}, {'telescope_name': 'Javalambre Survey Telescope (JAST/T250)[4]', 'aperture_m': '2.55\xa0m ', 'aperture_in': '100\xa0in)', 'mirror_type': 'Single', 'host_nationality': 'International', 'site': 'Javalambre Observatory, Spain (Z32)', 'year_built': 'TBA'}, {'telescope_name': 'Isaac Newton Telescope (INT)', 'aperture_m': '2.54\xa0m ', 'aperture_in': '100\xa0in)', 'mirror_type': 'Single', 'host_nationality': 'UK', 'site': "ORM, Canary Islands, Spain (RGO, England, UK until '79)", 'year_built': '1984'}, {'telescope_name': 'Irenee du Pont Telescope', 'aperture_m': '2.54\xa0m ', 'aperture_in': '100\xa0in)', 'mirror_type': 'Single', 'host_nationality': 'USA', 'site': 'Las Campanas Observatory, Coquimbo Region, Chile', 'year_built': '1976'}, {'telescope_name': 'Hooker 100-Inch Telescope', 'aperture_m': '2.54\xa0m ', 'aperture_in': '100\xa0in)', 'mirror_type': 'Single', 'host_nationality': 'USA', 'site': 'Mt. Wilson Observatory, California, USA', 'year_built': '1917'}  ... displaying 10 of 219 total bound parameter sets ...  {'telescope_name': 'Spacewatch 0.9m Telescope', 'aperture_m': '0.914\xa0m', 'aperture_in': '36″', 'mirror_type': 'Single', 'host_nationality': 'USA', 'site': 'Steward Observatory enclave at Kitt Peak National Observatory, Arizona, USA', 'year_built': 'Contracted 1915, Completed 1921'}, {'telescope_name': 'Yapp telescope', 'aperture_m': '0.914\xa0m', 'aperture_in': '36″', 'mirror_type': 'Single', 'host_nationality': 'U.K.', 'site': 'Royal Observatory, Greenwich+Herstmonceux', 'year_built': '1934-1990'})]
# (Background on this error at: http://sqlalche.me/e/13/9h9h)

# %%
exoplanets_df.to_sql(name='planets', con=engine, if_exists='append', index=False)
